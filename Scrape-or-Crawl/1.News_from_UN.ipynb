# %% [markdown]
# # Web-Scraping News from the United Nations site
# We will scrape the latest News-posts from UN's site and compile them to a Dataframe that can be exported to different file-types.

# %%
from bs4 import BeautifulSoup # The nice libraries
import urllib.request as ur, pandas as pd

# tag-tokens per post that we are looking for, unnecessary but kept here just in case
cards_ref = dict(title=['h2',{'class':'blog-shortcode-post-title'}],
                 meta=['p',{'class':'fusion-single-line-meta'}],
                 info=['div',{'class':'fusion-post-content-container'}]
                 )

# Collecting the HTML Cards/Panels per post on the 'News' section of the site
url = 'https://www.un.org/youthenvoy/news/'
req = ur.Request(url, headers = {'User-Agent': 'Someone'})
page_content = ur.urlopen(req).read()
soup = BeautifulSoup(page_content, "html.parser")
cards = soup.find_all("div", attrs={'class':'fusion-post-content post-content'})

print("Page-1 Posts collected (in HTML) from UN's News-page.")
# Out:
# Page-1 Posts collected (in HTML) from UN's News-page.

# %% [markdown]
# ### Collecting details per News-post (title, date, etc...)

# %%
print('Details being collected per news-post card, an example of the first 3:\n')

UN_news_cards = []
for i, card in enumerate(cards, 1):
    
    card_link = card.find('a', href=True)
    title = card_link.text.strip() # Or: card.find('h2').text
    date = card.find('span').text.strip()
    subtext = card.find('div',
                        attrs={'class':'fusion-post-content-container'}).text.strip()
    card_url = card_link['href']
    
    if i < 4: 
        print(f'Title:\t\t\t{title}\n'+
              f'Date:\t\t\t{date}\n'+
              f'Subtext:\t\t{subtext}...\n'+
              f'Read more (post-link):\t{card_link["href"]}\n\n')
    
    UN_news_cards.append([title, date, subtext, card_url])
# Out:
# Details being collected per news-post card, an example of the first 3:
#
# Title:			Launch of “Be Seen, Be Heard” Campaign
# Date:			11 May 2022
# Subtext:		The United Nations Secretary-General’s Envoy on Youth and The Body Shop launch global collaboration calling for more young voices in the halls of power   The Body Shop and United Nations Secretary-General’s Envoy on Youth...
# Read more (post-link):	https://www.un.org/youthenvoy/2022/05/launch-of-the-be-seen-be-heard-campaign/
#
#
# Title:			World leaders renew commitment to “Youth, Peace and Security” agenda
# Date:			21 January 2022
# Subtext:		Governments announce new actions to meaningfully include youth in peacebuilding efforts at the High-Level Global Conference on Youth-Inclusive Peace Processes 21 January 2022 (Doha, Qatar) —  At the virtual High-Level Global Conference on Youth-Inclusive...
# Read more (post-link):	https://www.un.org/youthenvoy/2022/01/world-leaders-renew-commitment-to-youth-peace-and-security-agenda/
#
#
# Title:			First-ever Global Report on Protecting Young People in Civic Space Highlights Need for Stronger Global Protection Mechanisms
# Date:			18 June 2021
# Subtext:		The launch of the report comes alongside a high-level event organized by Office of the UN Secretary-General’s Envoy on Youth focused on bringing young people’s protection concerns to the international agenda in a safe manner,...
# Read more (post-link):	https://www.un.org/youthenvoy/2021/06/first-ever-global-report-on-protecting-young-people-in-civic-space-highlights-need-for-stronger-global-protection-mechanisms/

# %% [markdown]
# ### News-Posts compiled as a Dataframe

# %%
UN_news_df = pd.DataFrame(UN_news_cards, columns=['UN_News','Date','Subtext','Link'])

UN_news_df
# Out:
#                                             UN_News              Date  \
# 0             Launch of “Be Seen, Be Heard” Campaign       11 May 2022
# 1  World leaders renew commitment to “Youth, Peac...   21 January 2022
# 2  First-ever Global Report on Protecting Young P...      18 June 2021
# 3  Young Human Rights Defenders Adapting to COVID-19   9 December 2020
# 4  On International Volunteers Day, Meet Our Firs...   4 December 2020
# 5  Breaking gender barriers for young women parli...  25 November 2020
# 6  Statement Issued by the Office of the UN Secre...     14 April 2020
# 7  Want to be a Fellow? Apply Now! No more unpaid...   5 February 2020
# 8  UN Secretary-General’s Envoy on Youth visits G...  24 December 2019
# 9                                Summer of Solutions  29 November 2019
#
#                                              Subtext  \
# 0  The United Nations Secretary-General’s Envoy o...
# 1  Governments announce new actions to meaningful...
# 2  The launch of the report comes alongside a hig...
# 3  Celebrating Youth Resilience & Creativity on I...
# 4  5 December 2020     Earlier this year, the Off...
# 5  Twenty-five years after the Beijing Declaratio...
# 6  The Office of the UN Secretary-General’s Envoy...
# 7  The Office of the Secretary-General’s Envoy on...
# 8  In October 2019, the United Nations Secretary-...
# 9  As the effects of climate change become more a...
#
#                                                 Link
# 0  https://www.un.org/youthenvoy/2022/05/launch-o...
# 1  https://www.un.org/youthenvoy/2022/01/world-le...
# 2  https://www.un.org/youthenvoy/2021/06/first-ev...
# 3  https://www.un.org/youthenvoy/2020/12/young-hu...
# 4  https://www.un.org/youthenvoy/2020/12/on-inter...
# 5  https://www.un.org/youthenvoy/2020/11/breaking...
# 6  https://www.un.org/youthenvoy/2020/04/statemen...
# 7  https://www.un.org/youthenvoy/2020/02/want-to-...
# 8  https://www.un.org/youthenvoy/2019/12/un-secre...
# 9  https://www.un.org/youthenvoy/2019/11/summer-o...

# %% [markdown]
# Some may prefer a dataframe with dates as our index, lets set it this way with "Dates" as date-time objects:

# %%
datetime_index = pd.to_datetime(UN_news_df.Date)

UN_news_df.set_index(datetime_index, inplace=True)
UN_news_df.drop('Date', axis=1, inplace=True)

print("A cleaner dataframe indexed Date-times:")
UN_news_df
# Out:
# A cleaner dataframe indexed Date-times:
#                                                      UN_News  \
# Date
# 2022-05-11             Launch of “Be Seen, Be Heard” Campaign
# 2022-01-21  World leaders renew commitment to “Youth, Peac...
# 2021-06-18  First-ever Global Report on Protecting Young P...
# 2020-12-09  Young Human Rights Defenders Adapting to COVID-19
# 2020-12-04  On International Volunteers Day, Meet Our Firs...
# 2020-11-25  Breaking gender barriers for young women parli...
# 2020-04-14  Statement Issued by the Office of the UN Secre...
# 2020-02-05  Want to be a Fellow? Apply Now! No more unpaid...
# 2019-12-24  UN Secretary-General’s Envoy on Youth visits G...
# 2019-11-29                                Summer of Solutions
#
#                                                       Subtext  \
# Date
# 2022-05-11  The United Nations Secretary-General’s Envoy o...
# 2022-01-21  Governments announce new actions to meaningful...
# 2021-06-18  The launch of the report comes alongside a hig...
# 2020-12-09  Celebrating Youth Resilience & Creativity on I...
# 2020-12-04  5 December 2020     Earlier this year, the Off...
# 2020-11-25  Twenty-five years after the Beijing Declaratio...
# 2020-04-14  The Office of the UN Secretary-General’s Envoy...
# 2020-02-05  The Office of the Secretary-General’s Envoy on...
# 2019-12-24  In October 2019, the United Nations Secretary-...
# 2019-11-29  As the effects of climate change become more a...
#
#                                                          Link
# Date
# 2022-05-11  https://www.un.org/youthenvoy/2022/05/launch-o...
# 2022-01-21  https://www.un.org/youthenvoy/2022/01/world-le...
# 2021-06-18  https://www.un.org/youthenvoy/2021/06/first-ev...
# 2020-12-09  https://www.un.org/youthenvoy/2020/12/young-hu...
# 2020-12-04  https://www.un.org/youthenvoy/2020/12/on-inter...
# 2020-11-25  https://www.un.org/youthenvoy/2020/11/breaking...
# 2020-04-14  https://www.un.org/youthenvoy/2020/04/statemen...
# 2020-02-05  https://www.un.org/youthenvoy/2020/02/want-to-...
# 2019-12-24  https://www.un.org/youthenvoy/2019/12/un-secre...
# 2019-11-29  https://www.un.org/youthenvoy/2019/11/summer-o...

# %% [markdown]
# ### Collecting a range of news-posts from the UN site
# We would first have to find how many pages or news-stories have been published in the site so far, and then we can iterate our above processes of news-post collection per news-page.

# %%
pages_url = url + 'pages/'

print("Indication of the total number of news-posts in the site:")
soup.find('a', attrs={'title':'News stories'}).text
# Out:
# Indication of the total number of news-posts in the site:
# 'News for Youth (312)'

# %% [markdown]
# Since we collected a total of *10 posts* in page-1 of the site, the math says there should be **32 pages** of news-posts to collect in total.

# %%
total_posts = 312
posts_per_page = UN_news_df.shape[0]
post_pages, remaining_posts = divmod(total_posts, posts_per_page)
post_pages += 1 if 0 < remaining_posts <= posts_per_page else 0

print(f"Total number of News-posts \t= {total_posts},\n"+
      f"Number of News-posts per page \t= {posts_per_page},\n"+
      f"Total number of post-pages \t= {post_pages}\n")
# Out:
# Total number of News-posts 	= 312,
# Number of News-posts per page 	= 10,
# Total number of post-pages 	= 32

# %% [markdown]
# #### A function to get News-posts from a single page or a range of pages

# %%
import numpy as np

def UN_news(url='https://www.un.org/youthenvoy/news/page/%d', page=1, to_page = 0, as_df=True, save=False):
    
    if not isinstance(page, int):
        raise ValueError(f"Invalid {type(page)} page input, only numbers (integers) allowed.")
        
    url = url%page if page >= 0 else url.replace('page/%d','')
    
    # Collecting page-content via BeautifulSoup
    req = ur.Request(url, headers = {'User-Agent': 'Someone'})
    page_content = ur.urlopen(req).read()
    soup = BeautifulSoup(page_content, "html.parser")
    cards = soup.find_all("div", attrs={'class':'fusion-post-content post-content'})
    
    # Loop-collection of details per News-post on page.
    UN_news_cards = []
    for i, card in enumerate(cards, 1):

        card_link = card.find('a', href=True)
        title = card_link.text.strip() # Or: card.find('h2').text
        date = card.find('span').text.strip()
        subtext = card.find('div',
                            attrs={'class':'fusion-post-content-container'}).text.strip()
        card_url = card_link['href']

        UN_news_cards.append([title, date, subtext, card_url])
    
    # Pages-Recursion: Add more pages of news-posts until the final page ("to_page")
    if to_page > page:
        for i, pg in enumerate(range(page+1, to_page+1), 1):
            page_posts = UN_news(page=pg, as_df=False, save=True)
            UN_news_cards += page_posts
            
            page_in10s = i%10
            
            if page_in10s == 0:
                if i < 11:
                    print("Scraped the first 10 pages.")
                else:
                    print("Scraped the next 10 pages.")
            
            if i == (to_page - page + 1):
                print("Last page reached! (all scraped)")
    
    # If we want to return our results as a dataframe (date-time indexed)
    if as_df: 
        UN_news_df = pd.DataFrame(UN_news_cards, columns=['UN_News','Date','Subtext','Link'])
        datetime_index = pd.to_datetime(UN_news_df.Date)

        UN_news_df.set_index(datetime_index, inplace=True)
        UN_news_df.drop('Date', axis=1, inplace=True)
        
        UN_news_cards = UN_news_df
    
    if save: # This is mostly for saving progress of iterative results (multiple page scraping)
        np.save('news_from_UN', {'posts':UN_news_cards}, allow_pickle=True)
    
    return UN_news_cards

# %% [markdown]
# #### Testing our function to collect News-posts of the next two pages

# %%
from ttictoc import tic, toc # To track code run-time

tic()
pages_2to3 = UN_news(page=2, to_page=3)

print(f"Total time taken to scrape news pages 2 - 3: {round(toc(), 3)} seconds")
# Out:
# Total time taken to scrape news pages 2 - 3: 35.135 seconds

# %%
pages_2to3
# Out:
#                                                      UN_News  \
# Date
# 2019-06-25             UN Youth Envoy at Lisboa+21 Conference
# 2019-06-22         UN Youth Envoy Visit to West Bank and Gaza
# 2019-06-20                     UN Youth Envoy visit to Jordan
# 2019-06-05    UN Youth Envoy at Women Deliver Conference 2019
# 2019-05-21  UN Youth Envoy at Global Platform for Disaster...
# 2019-05-10  Speak Up to Save Lives – The 5th UN Global Roa...
# 2019-05-10  UN Youth Envoy Visit to Belgrade, Pristina and...
# 2019-05-07                            2019 ECOSOC Youth Forum
# 2019-03-27  UN Secretary-General’s Envoy on Youth at the 6...
# 2019-02-11  First International Symposium on Youth Partici...
# 2018-12-31                               Happy New Year, 2019
# 2018-11-01  UN Secretary-General‘s Envoy on Youth at Unite...
# 2018-10-12    Global South-South Development (GSSD) EXPO 2018
# 2018-08-31  Visit of the UN Secretary-General’s Envoy on Y...
# 2018-08-16  High-Level Political Forum 2018: “Transformati...
# 2018-08-07                 International Youth Day Observance
# 2018-07-12         2018 ECOSOC Humanitarian – Affairs Segment
# 2017-06-22  UN Human Rights Council calls for “full realiz...
# 2017-04-28  UNICEF Advocate Ishmael Beah helps give a voic...
# 2017-04-18  UN cultural agency promotes power of youth to ...
#
#                                                       Subtext  \
# Date
# 2019-06-25  21 years ago in 1998, the Lisbon Declaration w...
# 2019-06-22  On June 19, I arrived on my first visit to Eas...
# 2019-06-20  I recently returned from my mission to Jordan....
# 2019-06-05  At the beginning of June, I had the opportunit...
# 2019-05-21  In a world where more disasters are caused by ...
# 2019-05-10  According to UN, nearly 1.3 million people di...
# 2019-05-10  Three cities in one week! I just came back fro...
# 2019-05-07  On 8-9 April 2019, the 8th Economic and Social...
# 2019-03-27  The sixty-third session of the Commission on t...
# 2019-02-11  Dear friends and fellow young people, I am exc...
# 2018-12-31  Dear Friends, This first year and a half, has ...
# 2018-11-01  On 18 September 2018, United Nations’ (UN) Mem...
# 2018-10-12  The 2018 GSSD Expo is taking place at the Unit...
# 2018-08-31  The United Nations Secretary-General’s Envoy o...
# 2018-08-16  UN Photo/ Loey Felipe  This year the annual Hi...
# 2018-08-07  Remarks by Jayathma Wickramanayake, UN Secreta...
# 2018-07-12  This year’s ECOSOC Humanitarian Affairs Segmen...
# 2017-06-22  During its 35th Session the United Nations Hum...
# 2017-04-28  Via UNICEF   AMMAN, 27 April 2017 – Ishmael Be...
# 2017-04-18  From UN News Young people from around the worl...
#
#                                                          Link
# Date
# 2019-06-25  https://www.un.org/youthenvoy/2019/06/un-youth...
# 2019-06-22  https://www.un.org/youthenvoy/2019/06/un-youth...
# 2019-06-20  https://www.un.org/youthenvoy/2019/06/un-youth...
# 2019-06-05      https://www.un.org/youthenvoy/2019/06/130275/
# 2019-05-21  https://www.un.org/youthenvoy/2019/05/un-youth...
# 2019-05-10  https://www.un.org/youthenvoy/2019/05/speak-up...
# 2019-05-10  https://www.un.org/youthenvoy/2019/05/un-youth...
# 2019-05-07  https://www.un.org/youthenvoy/2019/05/2019-eco...
# 2019-03-27  https://www.un.org/youthenvoy/2019/03/un-secre...
# 2019-02-11  https://www.un.org/youthenvoy/2019/02/first-in...
# 2018-12-31  https://www.un.org/youthenvoy/2018/12/happy-ne...
# 2018-11-01  https://www.un.org/youthenvoy/2018/11/un-secre...
# 2018-10-12  https://www.un.org/youthenvoy/2018/10/global-s...
# 2018-08-31  https://www.un.org/youthenvoy/2018/08/visit-un...
# 2018-08-16  https://www.un.org/youthenvoy/2018/08/high-lev...
# 2018-08-07  https://www.un.org/youthenvoy/2018/08/internat...
# 2018-07-12  https://www.un.org/youthenvoy/2018/07/2018-eco...
# 2017-06-22  https://www.un.org/youthenvoy/2017/06/un-human...
# 2017-04-28  https://www.un.org/youthenvoy/2017/04/unicef-a...
# 2017-04-18  https://www.un.org/youthenvoy/2017/04/un-cultu...

# %% [markdown]
# The above collection of the next **two pages of news-posts** took approx. **~35 seconds** of scraping time. This means that for the next **29 pages** (left of news-posts in the site), it should take around **8 minutes** (507.5 seconds) to get! Lets find out:

# %%
tic()

next_pages = UN_news(page=4, to_page=32)

end_time = round(toc(), 3)

print(f"Total time taken to scrape the next 29 pages: {end_time} seconds! ({end_time/60} minutes)")
# Out:
# Scraped the first 10 pages.
# Scraped the next 10 pages.
# Total time taken to scrape the next 29 pages: 487.209 seconds! (8.12015 minutes)

# %% [markdown]
# We indeed took approx. ~8 minutes to collect the rest of the news-posts. Lets finally compile our above dataframes to have a complete table of all news-posts from the site.

# %%
next_pages
# Out:
#                                                      UN_News  \
# Date
# 2017-04-17  Young entrepreneurs in Tanzania: Where are the...
# 2017-04-17    Exploring opportunities to build youth capacity
# 2017-04-05  ‘Traditional leaders stand up to protect youth...
# 2017-03-30  From where I stand: “We barely had a meal in t...
# 2017-03-23  Young women call for increased women’s leaders...
# ...                                                       ...
# 2013-08-26  UN Envoy on Youth Announces Partnership with I...
# 2013-08-25  In Venezuela, Music Provides Hope for Impoveri...
# 2013-08-25  UN Envoy on Youth Attends the Child and Youth ...
# 2013-08-25  UNV youth volunteers welcomed at Czech Republi...
# 2013-08-25  Young Thai Wins UNEP’s Global Art and Environm...
#
#                                                       Subtext  \
# Date
# 2017-04-17  Via ILO The ILO Kazi Nje Nje BDS apprenticeshi...
# 2017-04-17  Via UN Volunteers   Mr Toily Kurbanov, Deputy ...
# 2017-04-05  Via UNFPA SHISELWENI, Swaziland – “We have hig...
# 2017-03-30  From UN Women Florence Luanda Maheshe found he...
# 2017-03-23  From UN Women Young women attending the 61st s...
# ...                                                       ...
# 2013-08-26  On 17 July 2013, the UN Secretary-General’s En...
# 2013-08-25  Nehyda Alas, a teacher and director of Venezue...
# 2013-08-25  On 7 May, UN Secretary General’s Envoy on Yout...
# 2013-08-25  by Veronika Jemelikova Seven young Czech natio...
# 2013-08-25  On 30 July 2013, 13-year-old Chiratchaya Kaeok...
#
#                                                          Link
# Date
# 2017-04-17  https://www.un.org/youthenvoy/2017/04/young-en...
# 2017-04-17  https://www.un.org/youthenvoy/2017/04/explorin...
# 2017-04-05  https://www.un.org/youthenvoy/2017/04/traditio...
# 2017-03-30  https://www.un.org/youthenvoy/2017/03/stand-ba...
# 2017-03-23  https://www.un.org/youthenvoy/2017/03/young-wo...
# ...                                                       ...
# 2013-08-26  https://www.un.org/youthenvoy/2013/08/envoy-on...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/in-venez...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/envoy-on...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/unv-yout...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/young-th...
#
# [282 rows x 3 columns]

# %% [markdown]
# ### All News-posts from the UN site (until the latest from May-11th 2022)

# %%
pd.concat([UN_news_df, pages_2to3, next_pages])
# Out:
#                                                      UN_News  \
# Date
# 2022-05-11             Launch of “Be Seen, Be Heard” Campaign
# 2022-01-21  World leaders renew commitment to “Youth, Peac...
# 2021-06-18  First-ever Global Report on Protecting Young P...
# 2020-12-09  Young Human Rights Defenders Adapting to COVID-19
# 2020-12-04  On International Volunteers Day, Meet Our Firs...
# ...                                                       ...
# 2013-08-26  UN Envoy on Youth Announces Partnership with I...
# 2013-08-25  In Venezuela, Music Provides Hope for Impoveri...
# 2013-08-25  UN Envoy on Youth Attends the Child and Youth ...
# 2013-08-25  UNV youth volunteers welcomed at Czech Republi...
# 2013-08-25  Young Thai Wins UNEP’s Global Art and Environm...
#
#                                                       Subtext  \
# Date
# 2022-05-11  The United Nations Secretary-General’s Envoy o...
# 2022-01-21  Governments announce new actions to meaningful...
# 2021-06-18  The launch of the report comes alongside a hig...
# 2020-12-09  Celebrating Youth Resilience & Creativity on I...
# 2020-12-04  5 December 2020     Earlier this year, the Off...
# ...                                                       ...
# 2013-08-26  On 17 July 2013, the UN Secretary-General’s En...
# 2013-08-25  Nehyda Alas, a teacher and director of Venezue...
# 2013-08-25  On 7 May, UN Secretary General’s Envoy on Yout...
# 2013-08-25  by Veronika Jemelikova Seven young Czech natio...
# 2013-08-25  On 30 July 2013, 13-year-old Chiratchaya Kaeok...
#
#                                                          Link
# Date
# 2022-05-11  https://www.un.org/youthenvoy/2022/05/launch-o...
# 2022-01-21  https://www.un.org/youthenvoy/2022/01/world-le...
# 2021-06-18  https://www.un.org/youthenvoy/2021/06/first-ev...
# 2020-12-09  https://www.un.org/youthenvoy/2020/12/young-hu...
# 2020-12-04  https://www.un.org/youthenvoy/2020/12/on-inter...
# ...                                                       ...
# 2013-08-26  https://www.un.org/youthenvoy/2013/08/envoy-on...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/in-venez...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/envoy-on...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/unv-yout...
# 2013-08-25  https://www.un.org/youthenvoy/2013/08/young-th...
#
# [312 rows x 3 columns]

# %% [markdown]
# #### Saving our dataframe as a dictionary-contained numpy-file
# We can save the data as other file-types too (csv, excel, etc), numpy is preferred given it's minimal file-size storage. And we are keeping it "dictionary-contained" in numpy to keep it's column names and attributes (to be assigned) intact when loading the data later.

# %%
all_newsposts = pd.concat([UN_news_df, pages_2to3, next_pages])
all_newsposts.attrs = {'news_url':url, 'news_pages':post_pages}

np.save('news_from_UN', {'df' : all_newsposts}, allow_pickle = True)

print("Saved! Asalamualaikum.")
# Out:
# Saved! Asalamualaikum.
