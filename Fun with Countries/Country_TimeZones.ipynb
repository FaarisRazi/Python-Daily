# %% [markdown]
# # Country Coordinates and TimeZones
# With the saved countries dataset (my repo -> Python-Daily/Fun with Countries), we will fetch the lat-long coordinates and timezone for our list of countries.

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import requests
import io

# Fetching our dataset from my Github repo (using the bytesIO process for a numpy-file case)
url = 'https://github.com/FaarisRazi/Python-Daily/blob/main/Fun%20with%20Countries/countries_geo.npy'
response = requests.get(url+'?raw=true')
response.raise_for_status()
bytesIO_obj = io.BytesIO(response.content)

country_df = np.load(bytesIO_obj, allow_pickle = True).item()['df']
country_df = country_df[['iso_a3']] # Just keeping the ISO-codes column
country_df.head()
# Out:
#             iso_a3
# country
# Aruba          ABW
# Afghanistan    AFG
# Angola         AGO
# Anguilla       AIA
# Albania        ALB

# %% [markdown]
# ### Getting every Country's Coordinates
# To geocode our country's addresses and obtain their lat-long coordinates, the **geocoder** API does the job!
# *Source*: https://geocoder.readthedocs.io/api.html
#
# Here's a test in fetching some random country's coordinates via ArcGIS in geocoder (Google is an option too).

# %%
from ttictoc import tic, toc # To track the time
from geocoder import arcgis
from random import choice

random_country = choice(country_df.index)

tic()
geo_obj =  arcgis(random_country)
coords = geo_obj.latlng

print(f"ArcGIS test for the Coordinates of {random_country} is:"+
      f"\nLatitude = {coords[0]}\nLongitude = {coords[1]}\n"+
      f"\n\nGeocoding time taken: {round(toc(), 3)} seconds.")
# Out:
# ArcGIS test for the Coordinates of Luxembourg is:
# Latitude = 49.776828429000034
# Longitude = 6.092325247000076
#
#
# Geocoding time taken: 0.901 seconds.

# %% [markdown]
# To geocode **multiple addresses** as in our case, we need "persistent HTTP connection" with requests.Session() as per the geocoder's API docs (see *Using a Session* section).

# %%
country_coords = {}
with requests.Session() as session:
    
    for i, country in enumerate(country_df.index, 1):
        coords = arcgis(country, session=session).latlng
        
        country_coords[country] = coords
        
        # For tracking progress,
        if not i%20: # print every 20th country's coordinates.
            print(f"{country}'s:\t{coords}")

print("All {country_df.shape[0]} country's coordinates collected!")
# Out:
# Belgium's:	[50.640682937000065, 4.661070427000027]
# Canada's:	[60.108670000000075, -113.64257999999995]
# Cyprus's:	[35.05017420900003, 33.22622977900005]
# Federated States of Micronesia's:	[6.880382388000044, 158.22751848500002]
# Croatia's:	[45.11867958500005, 15.435623834000069]
# Kazakhstan's:	[48.18310616400004, 67.19504548200007]
# Macao S.A.R's:	[22.15778000000006, 113.55972000000008]
# Malawi's:	[-13.50952235099993, 34.24073561300003]
# Philippines's:	[14.164862797000069, 120.8616300000001]
# Serranilla Bank's:	[15.84907000000004, -79.85961999999995]
# Syria's:	[35.01280854600003, 38.50527333900004]
# US Naval Base Guantanamo Bay's:	[20.48028000000005, -74.61693999999994]
# {'Aruba': [12.50908537500004, -69.97050301699994],
#  'Afghanistan': [33.831137065000064, 66.02471179700007],
#  'Angola': [-12.293655625999975, 17.545335193000028],
#  'Anguilla': [18.224602780000055, -63.05962295599994],
#  'Albania': [41.13455328400005, 20.06420643100006],
#  'Iran': [32.55801995200005, 54.305910263000044],
#  'Iraq': [33.03897467000007, 43.77717241800008],
#  'Iceland': [64.98695685900003, -18.582382345999974],
#  'Israel': [31.97771151200004, 34.97921769200008],
#  'Italy': [42.833330000000046, 12.833330000000046],
#  'Jamaica': [18.157695292000028, -77.31110640499998],
#  'Jersey': [49.21402591200007, -2.1327190749999545],
#  'Jordan': [31.248189480000065, 36.78810430300007],
#  'Japan': [36.655226998000046, 139.27149500000007],
#  'Baykonur Cosmodrome': [34.18231300000008, -118.396459],
#  'Siachen Glacier': [35.19861000000003, 77.20139000000006],
#  'Kazakhstan': [48.18310616400004, 67.19504548200007],
#  'Kenya': [0.5284306580000475, 37.88969855200003],
#  'Kyrgyzstan': [41.43197845000003, 74.46759424400005],
#  'Cambodia': [12.709217848000037, 104.91106264800004],
#  'Kiribati': [1.8518405030000622, -157.35793263799997],
#  'Saint Kitts and Nevis': [17.33971168900007, -62.765603845999976],
#  'South Korea': [36.35627096300004, 127.80639593300009],
#  'Kosovo': [42.58150772100004, 20.891573227000038],
#  'Kuwait': [29.355337252000027, 47.61216588100007],
#  'Laos': [18.49549827900006, 103.76805746500008],
#  'Lebanon': [33.92144516600007, 35.893427744000064],
#  'Liberia': [6.447342577000029, -9.31038674499996],
#  'Libya': [27.041821576000075, 18.030819147000045],
#  'Saint Lucia': [13.898639726000056, -60.967300455999975],
#  'Liechtenstein': [47.14114224000008, 9.553182027000048],
#  'Sri Lanka': [7.617678409000064, 80.69863241800005],
#  'Lesotho': [-29.582324937999942, 28.24669362800006],
#  'Lithuania': [55.33693608100003, 23.900396649000072],
#  'Luxembourg': [49.776828429000034, 6.092325247000076],
#  'Latvia': [56.85460987000005, 24.926839006000023],
#  'Macao S.A.R': [22.15778000000006, 113.55972000000008],
#  'Saint Martin': [18.079517259000056, -63.06108125199995],
#  'Morocco': [32.00000000000006, -4.999999999999943],
#  'Monaco': [43.73170451200008, 7.424355000000048],
#  'Moldova': [47.20102827100004, 28.46370618900005],
#  'Madagascar': [-19.37694392999998, 46.69788267100006],
#  'Maldives': [4.175240000000031, 73.50928000000005],
#  'Mexico': [23.952824990000067, -102.54835341899997],
#  'Marshall Islands': [7.069111712000051, 171.2953100000001],
#  'Macedonia': [41.610517067000046, 21.715451030000054],
#  'Mali': [17.362972883000054, -3.5204716629999666],
#  'Malta': [35.92254885600005, 14.400072590000036],
#  'Myanmar': [21.100640956000063, 96.50375235400008],
#  'Montenegro': [42.796154744000034, 19.25209946500007],
#  'Mongolia': [46.83469147400007, 103.06763313100004],
#  'Northern Mariana Islands': [15.188824770000053, 145.75351048700009],
#  'Mozambique': [-18.249999999999943, 35.00000000000006],
#  'Mauritania': [20.25950735200007, -10.331488709999974],
#  'Montserrat': [16.739171964000036, -62.18928012099997],
#  'Mauritius': [-20.283556218999934, 57.57181746400005],
#  'Malawi': [-13.50952235099993, 34.24073561300003],
#  'Malaysia': [2.500000000000057, 112.50000000000011],
#  'Namibia': [-22.138976121999974, 17.22149898400005],
#  'New Caledonia': [-21.307791315999964, 165.70184184200002],
#  'Niger': [17.42088083400006, 9.401672665000035],
#  'Norfolk Island': [-29.037111789999983, 167.95238196200012],
#  'Nigeria': [9.593696882000074, 8.106777828000077],
#  'Nicaragua': [12.934455771000046, -85.00621251399997],
#  'Niue': [-19.052283097999975, -169.85845946899997],
#  'Netherlands': [52.24937529300007, 5.616126398000063],
#  'Norway': [62.00000000000006, 10.000000000000057],
#  'Nepal': [28.25913770300008, 83.94416346900005],
#  'Nauru': [-0.5285406929999681, 166.9341949400001],
#  'New Zealand': [-42.28723356399996, 172.34343250000006],
#  'Oman': [20.59793733300006, 56.10497815300005],
#  'Pakistan': [30.314282999000056, 70.21010363900007],
#  'Panama': [8.939604460000055, -79.97292613699994],
#  'Pitcairn Islands': [-24.37686651699994, -128.32274295999997],
#  'Peru': [-9.999999999999943, -75.99999999999994],
#  'Spratly Islands': [7.673622632000047, 111.66317726600005],
#  'Philippines': [14.164862797000069, 120.8616300000001],
#  'Palau': [7.421479662000024, 134.511600068],
#  'Papua New Guinea': [-6.475589906999971, 145.253800898],
#  'Poland': [52.12379015400006, 19.39876898600005],
#  'Puerto Rico': [18.22260649800006, -66.46895343099999],
#  'North Korea': [40.14182634600007, 127.1696919200001],
#  'Portugal': [39.59313904600003, -8.519812989999934],
#  'Paraguay': [-23.21981209599994, -58.41066601899996],
#  'Palestine': [31.91271978700007, 35.204684057000065],
#  'French Polynesia': [-17.67739793399994, -149.40097329699998],
#  'Qatar': [25.285444965000067, 51.19314832400005],
#  'Romania': [45.845854975000066, 24.973472215000072],
#  'Russia': [61.989526183000066, 96.80537153400007],
#  'Rwanda': [-1.9983949569999595, 29.956312610000055],
#  'Western Sahara': [24.65850293400007, -13.13948596199998],
#  'Saudi Arabia': [24.12136952900005, 44.548827060000065],
#  'Scarborough Reef': [15.133330000000058, 117.76667000000009],
#  'Sudan': [16.053254132000063, 30.009189122000066],
#  'South Sudan': [7.263460914000063, 30.343765666000024],
#  'Senegal': [14.363032568000051, -14.459259560999953],
#  'Serranilla Bank': [15.84907000000004, -79.85961999999995],
#  'Singapore': [1.2904100000000653, 103.85211000000004],
#  'South Georgia and South Sandwich Islands': [-54.20362450499994,
#   -36.90728999999993],
#  'Saint Helena': [-15.96527132999995, -5.707392691999928],
#  'Solomon Islands': [-9.622803767999926, 160.1602896490001],
#  'Sierra Leone': [8.558037771000045, -11.792031778999956],
#  'El Salvador': [13.733468471000037, -88.86567455199997],
#  'San Marino': [43.93817105200003, 12.463507795000055],
#  'Somaliland': [8.000000000000057, 45.00000000000006],
#  'Somalia': [4.40461606100007, 46.20310500000005],
#  'Saint Pierre and Miquelon': [46.85613316300004, -56.32282999999995],
#  'Republic of Serbia': [44.02936463900005, 20.804550522000056],
#  'Sao Tome and Principe': [0.2393107930000724, 6.602059996000037],
#  'Suriname': [3.9317774090000626, -56.01360780899995],
#  'Slovakia': [48.70870207100006, 19.487749068000028],
#  'Slovenia': [46.119554805000064, 14.821760495000035],
#  'Sweden': [64.71258554700006, 17.260487956000077],
#  'Swaziland': [-26.564951384999972, 31.497946670000033],
#  'Sint Maarten': [18.079517259000056, -63.06108125199995],
#  'Seychelles': [-4.678652263999936, 55.46726211600003],
#  'Syria': [35.01280854600003, 38.50527333900004],
#  'Turks and Caicos Islands': [21.758132630000034, -71.82311799799999],
#  'Chad': [15.376264850000041, 18.674165747000075],
#  'Togo': [8.539049810000051, 0.9744440640000676],
#  'Thailand': [15.11680278700004, 101.01223920600006],
#  'Tajikistan': [39.00000000000006, 71.00000000000006],
#  'Turkmenistan': [39.19335818400003, 59.17525293600005],
#  'East Timor': [-8.820319216999962, 125.8524027200001],
#  'Tonga': [-21.158658678999927, -175.27562999999998],
#  'Trinidad and Tobago': [10.47267427600002, -61.26048813699998],
#  'Tunisia': [34.11631798800005, 9.60851649600005],
#  'Turkey': [39.066250645000025, 35.142286272000035],
#  'Tuvalu': [-7.47055919099995, 178.67158000000006],
#  'Taiwan': [23.752816021000058, 120.95346396100001],
#  'United Republic of Tanzania': [-6.438400132999959, 34.995322712000075],
#  'Uganda': [1.513805689000037, 32.335706651000066],
#  'Ukraine': [49.02689837500003, 31.374926053000024],
#  'United States Minor Outlying Islands': [5.875525703000051,
#   -162.07479499999997],
#  'Uruguay': [-32.79326568999994, -56.02075792399995],
#  'United States of America': [39.39870315600007, -99.41461918999994],
#  'US Naval Base Guantanamo Bay': [20.48028000000005, -74.61693999999994],
#  'Uzbekistan': [41.58134563700003, 63.42188301400006],
#  'Vatican': [41.90225000000004, 12.45330000000007],
#  'Saint Vincent and the Grenadines': [13.201840619000052, -61.20075147199998],
#  'Venezuela': [7.120733800000039, -66.16282028899997],
#  'British Virgin Islands': [18.430308339000078, -64.59420749999998],
#  'United States Virgin Islands': [17.728114454000035, -64.81908749999997],
#  'Vietnam': [16.166670000000067, 107.83333000000005],
#  'Vanuatu': [-15.241355872999975, 166.8727570740001],
#  'Wallis and Futuna': [-13.285018271999945, -176.20445035499998],
#  'Akrotiri Sovereign Base Area': [34.60184000000004, 32.954090000000065],
#  'Samoa': [-13.62080777999995, -172.44733321399997],
#  'Yemen': [15.905205994000028, 47.59395262500004],
#  'South Africa': [-28.997182287999976, 25.085049940000033],
#  'Zambia': [-14.46880366299996, 28.76797288100005],
#  'Zimbabwe': [-19.016205470999978, 29.884276749000037]}

# %%
country_df[['Latitude','Longitude']] = pd.DataFrame(country_df.index.map(country_coords.get).tolist(),
                                                   index = country_df.index)

country_df
# Out:
#              iso_a3                      (Latitude, Longitude)   Latitude  \
# country
# Aruba           ABW    [12.50908537500004, -69.97050301699994]  12.509085
# Afghanistan     AFG    [33.831137065000064, 66.02471179700007]  33.831137
# Angola          AGO  [-12.293655625999975, 17.545335193000028] -12.293656
# Anguilla        AIA   [18.224602780000055, -63.05962295599994]  18.224603
# Albania         ALB     [41.13455328400005, 20.06420643100006]  41.134553
# ...             ...                                        ...        ...
# Samoa           WSM  [-13.62080777999995, -172.44733321399997] -13.620808
# Yemen           YEM    [15.905205994000028, 47.59395262500004]  15.905206
# South Africa    ZAF  [-28.997182287999976, 25.085049940000033] -28.997182
# Zambia          ZMB    [-14.46880366299996, 28.76797288100005] -14.468804
# Zimbabwe        ZWE  [-19.016205470999978, 29.884276749000037] -19.016205
#
#                Longitude
# country
# Aruba         -69.970503
# Afghanistan    66.024712
# Angola         17.545335
# Anguilla      -63.059623
# Albania        20.064206
# ...                  ...
# Samoa        -172.447333
# Yemen          47.593953
# South Africa   25.085050
# Zambia         28.767973
# Zimbabwe       29.884277
#
# [255 rows x 4 columns]

# %% [markdown]
# ### Getting every Country's TimeZone
# Here's a function we will use to collect the TimeZones, with the *TimezoneFinder* package: (https://pypi.org/project/timezonefinder/).

# %%
from timezonefinder import TimezoneFinder

def gettz(coords):
    """
    Get the Timezone name of location coordinates via TimezoneFinder 
    API.

    Parameters
    ----------
    lat : float
        Latitude in degrees north
    lon : float
        Longitude in degrees east

    Returns
    -------
    Timezone: str
        TZ name of the location coordinates.
    """
   
    if type(coords) == str:
        coords = list(map(lambda x: float(x.strip()),coords.split(',')))

    lat, lon = coords

    tf = TimezoneFinder()

    try:
        timezone_name = tf.timezone_at(lng=lon, lat=lat)
        if timezone_name is None:
            timezone_name = tf.closest_timezone_at(lng=lon, lat=lat)

        return timezone_name
            # maybe even increase the search radius when it is still None
    except ValueError or NameError:
        # the coordinates were out of bounds
        pass # {handle error}

# %% [markdown]
# #### Timezones Collected:

# %%
country_df['timezone'] = country_df.apply(lambda x: gettz([x['Latitude'], x['Longitude']]), 
                 axis=1)

country_df
# Out:
#              iso_a3                      (Latitude, Longitude)   Latitude  \
# country
# Aruba           ABW    [12.50908537500004, -69.97050301699994]  12.509085
# Afghanistan     AFG    [33.831137065000064, 66.02471179700007]  33.831137
# Angola          AGO  [-12.293655625999975, 17.545335193000028] -12.293656
# Anguilla        AIA   [18.224602780000055, -63.05962295599994]  18.224603
# Albania         ALB     [41.13455328400005, 20.06420643100006]  41.134553
# ...             ...                                        ...        ...
# Samoa           WSM  [-13.62080777999995, -172.44733321399997] -13.620808
# Yemen           YEM    [15.905205994000028, 47.59395262500004]  15.905206
# South Africa    ZAF  [-28.997182287999976, 25.085049940000033] -28.997182
# Zambia          ZMB    [-14.46880366299996, 28.76797288100005] -14.468804
# Zimbabwe        ZWE  [-19.016205470999978, 29.884276749000037] -19.016205
#
#                Longitude             timezone
# country
# Aruba         -69.970503        America/Aruba
# Afghanistan    66.024712           Asia/Kabul
# Angola         17.545335        Africa/Luanda
# Anguilla      -63.059623     America/Anguilla
# Albania        20.064206        Europe/Tirane
# ...                  ...                  ...
# Samoa        -172.447333         Pacific/Apia
# Yemen          47.593953            Asia/Aden
# South Africa   25.085050  Africa/Johannesburg
# Zambia         28.767973        Africa/Lusaka
# Zimbabwe       29.884277        Africa/Harare
#
# [255 rows x 5 columns]
